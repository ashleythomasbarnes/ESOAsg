# %% [markdown]
# <img align='left' alt='ESO Logo' src='http://archive.eso.org/i/esologo.png'>
#
# # &nbsp; ESO Science Archive Programmatic: HOWTOs

# %% [markdown]
# # HOW TO compare ESO catalogues
#
# The ESO catalogue facility provides access to the collection of data that were produced by PIs of ESO programmes and then integrated into the ESO science archive through the Phase 3 process. The full list of available cataolgues could be found [here](https://www.eso.org/qi/).
#
# To access the data you can use the [_programmatic access_](http://archive.eso.org/programmatic/#TAP) via the `tap_cat` TAP Service. The module `archive_catalogues` provides some simple `python` wrapper around this. For more details please see the [ESOAsg documentation](https://esoasg.readthedocs.io/en/latest/)

# %% [markdown]
# ---
# ## <a id='imports'>0. Imports - inc. ESOAsg package</a>

# %%
from ESOAsg import archive_catalogues # ESO Archive Catalogues

from astropy.coordinates import SkyCoord # Astropy coordinates
from astropy.io import fits # Astropy FITS files
import astropy.constants as const # Astropy constants
import astropy.units as u # Astropy units
import matplotlib.pyplot as plt # Matplotlib
import numpy as np # Numpy

# Set the default font size and weight for plots
plt.rcParams['font.weight'] = 'bold'
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams['axes.titleweight'] = 'bold'
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['xtick.top'] = True
plt.rcParams['xtick.minor.visible'] = True
plt.rcParams['ytick.direction'] = 'in'
plt.rcParams['ytick.right'] = True
plt.rcParams['ytick.minor.visible'] = True
plt.rcParams['figure.dpi'] = 200

# %% [markdown]
# ---
# ## <a id='Check catalogue'>1. Check the catalogue you want to query </a>
#
# To begin, you need to know which catalogues you are interested to query. If in doubt, you can either check the [query interface webpage](https://www.eso.org/qi/) or you can obtain an astropy table of all catalogues (and all their versions) using:
# ```python
# archive_catalogues.all_catalogues_info()
# ```
#
# For this example, we will compare the physical parameter space covered by the catalogues [GAIAESO](http://archive.eso.org/scienceportal/home?data_collection=GAIAESO) and [AMBRE](http://archive.eso.org/scienceportal/home?data_collection=AMBRE). The content of which can be explored by running:
# ```python
# archive_catalogues.all_catalogues_info(collections=['GAIAESO', 'AMBRE'])
# ```

# %%
catalogues = archive_catalogues.catalogues_info(collections=['GAIAESO', 'AMBRE'])
catalogues['collection', 'title', 'version', 'description', 'table_name'].show_in_notebook(display_length=5, show_row_index=False)
# Out:
# <i>Table length=5</i>
# <table id="table140551475028848-110957" class="table-striped table-bordered table-condensed">
# <thead><tr><th>collection</th><th>title</th><th>version</th><th>description</th><th>table_name</th></tr></thead>
# <tr><td>AMBRE</td><td>Atmospheric Parameters and Chemical Abundances from Stellar Spectra - HARPS</td><td>1</td><td>Stellar radial velocity, atmospheric parameters (effective temperature, surface gravity, mean metallicity [M/H]) and enrichment in alpha-elements ([alpha/Fe]) resulting from the automatic analysis of the ESO spectral data archives of the FEROS, UVES, HARPS and FLAMES instruments with the MATISSE algorithm. This third release concerns the HARPS data collected from 2003, October to 2010, October.</td><td>AMBRE_HARPS_V1</td></tr>
# <tr><td>AMBRE</td><td>Atmospheric Parameters and Chemical Abundances from Stellar Spectra - UVES</td><td>1</td><td>Stellar radial velocity, atmospheric parameters (effective temperature, surface gravity, mean metallicity [M/H]) and enrichment in alpha-elements ([alpha/Fe]) resulting from the automatic analysis of the ESO spectral data archives of the FEROS, UVES, HARPS and FLAMES instruments with the MATISSE algorithm. This first release concerns the UVES data collected from 2000, March to 2010, November.</td><td>AMBRE_UVES_V1</td></tr>
# <tr><td>AMBRE</td><td>Atmospheric Parameters and Chemical Abundances from Stellar Spectra</td><td>1</td><td>Stellar radial velocity, atmospheric parameters (effective temperature, surface gravity, mean metallicity [M/H]) and enrichment in alpha-elements ([alpha/Fe]) resulting from the automatic analysis of the ESO spectral data archives of the FEROS, UVES, HARPS and FLAMES instruments with the MATISSE algorithm. This first release concerns the FEROS data collected from 2005, October to 2009, December.</td><td>AMBRE_V1</td></tr>
# <tr><td>GAIAESO</td><td>GAIAESO catalogue of radial velocities</td><td>1</td><td>Radial velocities are released here for 110,762 objects, 97% of the objects for which spectra were released in GAIAESO DR4. For GIRAFFE, Jackson et al. (2015) estimates in a 0.25 km s-1 the maximum achieved precision (function of SNR, stellar parameters, and vsini). A lower precision is achieved with UVES (0.32 km s-1), due to the lack of simultaneous calibration exposures.</td><td>GES_2021_VRAD</td></tr>
# <tr><td>GAIAESO</td><td>Gaia-ESO spectroscopic survey</td><td>4</td><td>Gaia-ESO is a large public spectroscopic survey carried out with FLAMES, targeting 114916\nstars, systematically covering all major components of the Milky Way from halo to star-forming regions providing an homogeneous overview of the distributions of kinematics and elemental abundances.</td><td>GES_DR5_1_V1</td></tr>
# </table><style>table.dataTable {clear: both; width: auto !important; margin: 0 !important;}
# .dataTables_info, .dataTables_length, .dataTables_filter, .dataTables_paginate{
# display: inline-block; margin-right: 1em; }
# .paginate_button { margin-right: 5px; }
# </style>
# <script>
#
# var astropy_sort_num = function(a, b) {
#     var a_num = parseFloat(a);
#     var b_num = parseFloat(b);
#
#     if (isNaN(a_num) && isNaN(b_num))
#         return ((a < b) ? -1 : ((a > b) ? 1 : 0));
#     else if (!isNaN(a_num) && !isNaN(b_num))
#         return ((a_num < b_num) ? -1 : ((a_num > b_num) ? 1 : 0));
#     else
#         return isNaN(a_num) ? -1 : 1;
# }
#
# require.config({paths: {
#     datatables: 'https://cdn.datatables.net/1.10.12/js/jquery.dataTables.min'
# }});
# require(["datatables"], function(){
#     console.log("$('#table140551475028848-110957').dataTable()");
#
# jQuery.extend( jQuery.fn.dataTableExt.oSort, {
#     "optionalnum-asc": astropy_sort_num,
#     "optionalnum-desc": function (a,b) { return -astropy_sort_num(a, b); }
# });
#
#     $('#table140551475028848-110957').dataTable({
#         order: [],
#         pageLength: 5,
#         lengthMenu: [[5, 10, 25, 50, 100, 500, 1000, -1], [5, 10, 25, 50, 100, 500, 1000, 'All']],
#         pagingType: "full_numbers",
#         columnDefs: [{targets: [2], type: "optionalnum"}]
#     });
# });
# </script>

# %% [markdown]
# This allows to extract information such as `table_name` and `acknowledgment`:

# %%
tables = catalogues['table_name'].data
acknowledgments = catalogues['acknowledgment'].data
for table, acknowledgment in zip(tables, acknowledgments):
    print('The name of the table is: {}. \nThe corresponding acknowledgment is:\n{}.\n'.format(
        table, acknowledgment))
# Out:
# The name of the table is: AMBRE_HARPS_V1.
# The corresponding acknowledgment is:
# Please include the following acknowledgment in any published material that makes use of this data products: Based on observations made with ESO Telescopes at the La Silla or Paranal Observatories under programme ID(s) 077.D-0720(A), 072.C-0488(E), 078.D-0067(A), 077.C-0295(C), 078.C-0833(A), 077.D-0498(A), 077.C-0530(A), 076.C-0279(C), 076.D-0103(A), 076.C-0279(B), 076.C-0429(A), 077.D-0085(C), 077.C-0012(A), 60.A-9036(A), 076.C-0279(A), 078.D-0245(C), 076.D-0130(D), 078.C-0751(A), 077.C-0295(A), 075.C-0332(A), 077.C-0295(B), 078.C-0209(A), 076.D-0207(A), 078.C-0133(A), 078.C-0044(A), 077.C-0101(A), 077.C-0364(E), 077.D-0633(A), 078.C-0233(A), 076.C-0878(B), 076.D-0130(C), 077.C-0295(D), 078.D-0071(A), 078.D-0071(B), 076.D-0130(E), 076.C-0010(A), 078.D-0299(A), 077.C-0513(A), 077.C-0080(A), 078.C-0037(A), 078.D-0071(C), 078.C-0510(C), 078.D-0492(A), 078.C-0233(B), 079.D-0466(A), 079.D-0118(A), 079.C-0170(B), 079.C-0681(A), 079.C-0329(A), 079.C-0927(B), 079.C-0828(A), 078.C-0209(B), 079.D-0462(A), 079.D-0009(C), 079.D-0160(A), 180.C-0886(A), 078.D-0071(E), 080.D-0408(A), 079.C-0927(C), 079.C-0170(A), 080.C-0032(A), 079.D-0075(B), 080.C-0712(A), 080.D-0086(A), 079.D-0075(C), 079.C-0463(A), 079.C-0127(A), 080.C-0071(A), 078.C-0403(A), 079.C-0898(A), 079.C-0046(A), 080.D-0086(B), 079.D-0075(D), 079.D-0075(A), 080.C-0664(A), 079.D-0075(E), 078.C-0037(B), 080.D-0047(A), 080.D-0347(A), 078.D-0071(D), 080.D-0318(A), 080.D-0086(C), 082.C-0315(A), 081.C-0388(A), 081.D-0008(A), 080.D-01.
#
# The name of the table is: AMBRE_UVES_V1.
# The corresponding acknowledgment is:
# Please include the following acknowledgment in any publication that makes use of these data: Based on observations made with ESO Telescopes at the La Silla or Paranal Observatories. Data analysis by the OCA/ESO AMBRE project (Worley et al. 2012, A&A 542A, 48, and de Laverny et al. 2012, A&A 544A, 126), based on the MATISSE parametrisation algorithm (Recio-Blanco et al., 2006, MNRAS 370, 141)..
#
# The name of the table is: AMBRE_V1.
# The corresponding acknowledgment is:
# Please include the following acknowledgment in any publication that makes use of these data: Based on observations made with ESO Telescopes at the La Silla or Paranal Observatories. Data analysis by the OCA/ESO AMBRE project (Worley et al. 2012, A&A 542A, 48, and de Laverny et al. 2012, A&A 544A, 126), based on the MATISSE parametrisation algorithm (Recio-Blanco et al., 2006, MNRAS 370, 141)..
#
# The name of the table is: GES_2021_VRAD.
# The corresponding acknowledgment is:
# Please include the following acknowledgment in any published material that makes use of this data products: Based on observations made with ESO Telescopes at the La Silla or Paranal Observatories under programme ID(s) 072.D-0019(B), 072.D-0309(A), 072.D-0337(A), 072.D-0406(A), 072.D-0507(A), 072.D-0742(A), 072.D-0777(A), 073.C-0251(B,C,D,E,F), 073.D-0100(A), 073.D-0211(A), 073.D-0550(A), 073.D-0695(A), 073.D-0760(A), 074.D-0571(A), 075.C-0245(A,C,D,E,F), 075.C-0256(A), 075.D-0492(A), 076.B-0263(A), 076.D-0220(A), 077.C-0655(A), 077.D-0246(A), 077.D-0484(A), 078.D-0825(A,B,C), 079.B-0721(A), 079.D-0178(A), 079.D-0645(A), 079.D-0674(A,B,C), 079.D-0825(B,C,D), 080.B-0489(A), 080.B-0784(A), 080.C-0718(A), 081.D-0253(A), 081.D-0287(A), 082.D-0726(A), 083.B-0083(A), 083.D-0208(A), 083.D-0671(A), 083.D-0682(A), 083.D-0798(B), 084.D-0470(A), 084.D-0693(A), 084.D-0933(A), 085.D-0205(A), 086.D-0141(A), 087.D-0203(B), 087.D-0230(A), 087.D-0276(A), 088.B-0403(A), 088.B-0492(A), 088.C-0239(A), 088.D-0026(A,B,C), 088.D-0045(A), 089.D-0038(A), 089.D-0298(A), 089.D-0579(A), 090.D-0487(A), 091.D-0427(A), 092.D-0171(C), 092.D-0477(A), 093.D-0286(A), 093.D-0818(A), 094.D-0363(A), 094.D-0455(A), 171.D-0237(A), 187.B-0909(A), 188.B-3002, 193.B-0936, 193.D-0232(B,D), 197.B-1074(A,B,C,D,E,F,G,H), 278.D-5027(A),292.D-5043(A), 381.C-0270(A), 383.D-0412(A), 383.D-0594(A), 386.B-0009(A), 60.A-9143(A), 60.A-9800(E), 71.B-0414(A), 71.D-0065(A), 71.D-0127(A), 71.D-0205(A)..
#
# The name of the table is: GES_DR5_1_V1.
# The corresponding acknowledgment is:
# Please include the following acknowledgment in any published material that makes use of this data products: Based on observations made with ESO Telescopes at the La Silla or Paranal Observatories under programme ID(s) 072.D-0019(B), 072.D-0309(A), 072.D-0337(A), 072.D-0406(A), 072.D-0507(A), 072.D-0742(A), 072.D-0777(A), 073.C-0251(B), 073.C-0251(C), 073.C-0251(D), 073.C-0251(E), 073.C-0251(F), 073.D-0100(A), 073.D-0211(A), 073.D-0550(A), 073.D-0695(A), 073.D-0760(A), 074.D-0571(A), 075.C-0245(A), 075.C-0245(C), 075.C-0245(D), 075.C-0245(E), 075.C-0245(F), 075.C-0256(A), 075.D-0492(A), 076.B-0263(A), 076.D-0220(A), 077.C-0655(A), 077.D-0246(A), 077.D-0484(A), 078.D-0825(A), 078.D-0825(B), 078.D-0825(C), 079.B-0721(A), 079.D-0178(A), 079.D-0645(A), 079.D-0674(A), 079.D-0674(B), 079.D-0674(C), 079.D-0825(B), 079.D-0825(C), 079.D-0825(D), 080.B-0489(A), 080.B-0784(A), 080.C-0718(A), 081.D-0253(A), 081.D-0287(A), 082.D-0726(A), 083.B-0083(A), 083.D-0208(A), 083.D-0671(A), 083.D-0682(A), 083.D-0798(B), 084.D-0470(A), 084.D-0693(A), 084.D-0933(A), 085.D-0205(A), 086.D-0141(A), 087.D-0203(B), 087.D-0230(A), 087.D-0276(A), 088.B-0403(A), 088.B-0492(A), 088.C-0239(A), 088.D-0026(A), 088.D-0026(B), 088.D-0026(C), 088.D-0026(D), 088.D-0045(A), 089.D-0038(A), 089.D-0298(A), 089.D-0579(A), 090.D-0487(A), 091.D-0427(A), 092.D-0171(C), 092.D-0477(A), 093.D-0286(A), 093.D-0818(A), 094.D-0363(A), 094.D-0455(A), 171.D-0237(A), 187.B-0909(A), 188.B-3002(A), 188.B-3002(B), 188.B-3002(C), 188.B-3.

# %% [markdown]
# ## Select the physical parameters to compare
#
# You can glance the content of a catalogue by checking the name of the columns present in the associated list of collections:
# ```python
# archive_catalogues.columns_info(collections=['GAIAESO', 'AMBRE'])
# ```

# %%
archive_catalogues.columns_info(tables='GES_DR5_1_V1').show_in_notebook(display_length=5, show_row_index=False)
# Out:
# <i>Table length=350</i>
# <table id="table140551077882080-485627" class="table-striped table-bordered table-condensed">
# <thead><tr><th>table_name</th><th>column_name</th><th>ucd</th><th>datatype</th><th>description</th><th>unit</th></tr></thead>
# <tr><td>GES_DR5_1_V1</td><td>OBJECT</td><td>meta.id;meta.main</td><td>CHAR</td><td>GES object name from coordinates</td><td></td></tr>
# <tr><td>GES_DR5_1_V1</td><td>GES_FLD</td><td>meta.id</td><td>CHAR</td><td>GES field name from CASU</td><td></td></tr>
# <tr><td>GES_DR5_1_V1</td><td>GES_TYPE</td><td>meta.code.member</td><td>CHAR</td><td>GES Classification System of Target Programmes</td><td></td></tr>
# <tr><td>GES_DR5_1_V1</td><td>REC_SETUP</td><td>instr.setup</td><td>CHAR</td><td>Grating setups used for deriving recommended parameters</td><td></td></tr>
# <tr><td>GES_DR5_1_V1</td><td>RAVAIL_SETUP</td><td>instr.setup</td><td>CHAR</td><td>Grating setups used for deriving radial velocities</td><td></td></tr>
# <tr><td>GES_DR5_1_V1</td><td>SETUP</td><td>instr.setup</td><td>CHAR</td><td>Grating setups used for analysis</td><td></td></tr>
# <tr><td>GES_DR5_1_V1</td><td>REC_WG</td><td>meta.curation</td><td>CHAR</td><td>Working group deriving the recommended parameters</td><td></td></tr>
# <tr><td>GES_DR5_1_V1</td><td>RA</td><td>pos.eq.ra;meta.main</td><td>DOUBLE</td><td>Object Right Ascension</td><td>deg</td></tr>
# <tr><td>GES_DR5_1_V1</td><td>DECLINATION</td><td>pos.eq.dec;meta.main</td><td>DOUBLE</td><td>Object Declination</td><td>deg</td></tr>
# <tr><td>GES_DR5_1_V1</td><td>SNR</td><td>stat.snr</td><td>REAL</td><td>SNR of the spectrum used for deriving radial velocities</td><td></td></tr>
# <tr><td>GES_DR5_1_V1</td><td>TEFF</td><td>phys.temperature.effective</td><td>REAL</td><td>Effective Temperature</td><td>K</td></tr>
# <tr><td>GES_DR5_1_V1</td><td>E_TEFF</td><td>stat.error;phys.temperature.effective;meta.main</td><td>REAL</td><td>Error on TEFF</td><td>K</td></tr>
# <tr><td>GES_DR5_1_V1</td><td>NN_TEFF</td><td>meta.number;phys.temperature.effective</td><td>SMALLINT</td><td>number of nodes that calculated TEFF</td><td></td></tr>
# <tr><td>GES_DR5_1_V1</td><td>ENN_TEFF</td><td>stat.error;phys.temperature.effective</td><td>REAL</td><td>Error on TEFF derived from the nodes</td><td>K</td></tr>
# <tr><td>GES_DR5_1_V1</td><td>NNE_TEFF</td><td>meta.number;phys.temperature.effective</td><td>SMALLINT</td><td>number of nodes used to calculate ENN_TEFF</td><td></td></tr>
# <tr><td>GES_DR5_1_V1</td><td>LOGG</td><td>phys.gravity</td><td>REAL</td><td>Log Surface Gravity (gravity in cm/s**2)</td><td>log(cm/s**2)</td></tr>
# <tr><td>GES_DR5_1_V1</td><td>E_LOGG</td><td>stat.error;phys.gravity;meta.main</td><td>REAL</td><td>Error on LOGG</td><td>log(cm/s**2)</td></tr>
# <tr><td>GES_DR5_1_V1</td><td>NN_LOGG</td><td>meta.number;phys.gravity</td><td>SMALLINT</td><td>number of nodes that calculated LOGG</td><td></td></tr>
# <tr><td>GES_DR5_1_V1</td><td>ENN_LOGG</td><td>stat.error;phys.gravity</td><td>REAL</td><td>Error on LOGG derived from the nodes</td><td>dex</td></tr>
# <tr><td>GES_DR5_1_V1</td><td>NNE_LOGG</td><td>meta.number;phys.gravity</td><td>SMALLINT</td><td>number of nodes used to calculate ENN_LOGG</td><td></td></tr>
# <tr><td>GES_DR5_1_V1</td><td>FEH</td><td>phys.abund.Fe</td><td>REAL</td><td>Metallicity</td><td>dex</td></tr>
# <tr><td>GES_DR5_1_V1</td><td>E_FEH</td><td>stat.error;phys.abund.Fe;meta.main</td><td>REAL</td><td>Error on FEH</td><td>dex</td></tr>
# <tr><td>GES_DR5_1_V1</td><td>NN_FEH</td><td>meta.number;phys.abund.Fe</td><td>SMALLINT</td><td>number of nodes that calculated FEH</td><td></td></tr>
# <tr><td>GES_DR5_1_V1</td><td>ENN_FEH</td><td>stat.error;phys.abund.Fe</td><td>REAL</td><td>Error on FEH derived from the nodes</td><td>dex</td></tr>
# <tr><td>GES_DR5_1_V1</td><td>NNE_FEH</td><td>meta.number;phys.abund.Fe</td><td>SMALLINT</td><td>number of nodes used to calculate ENN_FEH</td><td></td></tr>
# <tr><td>GES_DR5_1_V1</td><td>XI</td><td>phys.veloc.microTurb</td><td>REAL</td><td>Microturbulent velocity</td><td>km/s</td></tr>
# <tr><td>GES_DR5_1_V1</td><td>E_XI</td><td>stat.error;phys.veloc.microTurb;meta.main</td><td>REAL</td><td>Error on XI</td><td>km/s</td></tr>
# <tr><td>GES_DR5_1_V1</td><td>NN_XI</td><td>meta.number;phys.veloc.microTurb</td><td>SMALLINT</td><td>number of nodes that calculated XI</td><td></td></tr>
# <tr><td>GES_DR5_1_V1</td><td>ENN_XI</td><td>stat.error;phys.veloc.microTurb</td><td>REAL</td><td>Error on XI derived from the nodes</td><td>km/s</td></tr>
# <tr><td>GES_DR5_1_V1</td><td>NNE_XI</td><td>meta.number;phys.veloc.microTurb</td><td>SMALLINT</td><td>number of nodes used to calculate ENN_XI</td><td></td></tr>
# <tr><td>GES_DR5_1_V1</td><td>VRAD</td><td>spect.dopplerVeloc.opt;meta.main</td><td>REAL</td><td>Radial Velocity</td><td>km/s</td></tr>
# <tr><td>GES_DR5_1_V1</td><td>E_VRAD</td><td>stat.error;spect.dopplerVeloc.opt</td><td>REAL</td><td>Error on VRAD</td><td>km/s</td></tr>
# <tr><td>GES_DR5_1_V1</td><td>ORIGIN_VRAD</td><td>meta.curation;spect.dopplerVeloc.opt</td><td>CHAR</td><td>working group and/or team that derived the radial velocities</td><td></td></tr>
# <tr><td>GES_DR5_1_V1</td><td>VRAD_OFFSET</td><td>spect.dopplerVeloc.opt;arith.diff</td><td>REAL</td><td>Offset applied to the measured radial velocity</td><td>km/s</td></tr>
# <tr><td>GES_DR5_1_V1</td><td>VRAD_FLAG</td><td>meta.code.qual;spect.dopplerVeloc.opt</td><td>SMALLINT</td><td>VRAD variability Flag (1 = inconsistent VRAD, or null)</td><td></td></tr>
# <tr><td>GES_DR5_1_V1</td><td>NF_VRAD_FLAG</td><td>meta.number;spect.dopplerVeloc.opt</td><td>SMALLINT</td><td>number of measurements used to calculate VRAD_FLAG</td><td></td></tr>
# <tr><td>GES_DR5_1_V1</td><td>VSINI</td><td>phys.veloc.rotat</td><td>REAL</td><td>projected rotational velocities</td><td>km/s</td></tr>
# <tr><td>GES_DR5_1_V1</td><td>E_VSINI</td><td>stat.error;phys.veloc.rotat</td><td>REAL</td><td>Error on VSINI</td><td>km/s</td></tr>
# <tr><td>GES_DR5_1_V1</td><td>LIM_VSINI</td><td>meta.code;phys.veloc.rotat</td><td>SMALLINT</td><td>Flag on VSINI (0=detection, 1=upper limit)</td><td></td></tr>
# <tr><td>GES_DR5_1_V1</td><td>LI1</td><td>phys.abund</td><td>REAL</td><td>Neutral Lithium Abundance</td><td>dex</td></tr>
# <tr><td>GES_DR5_1_V1</td><td>LIM_LI1</td><td>meta.code;phys.abund</td><td>SMALLINT</td><td>Flag on LI1 measurement type (0=detection, 1=upper limit)</td><td></td></tr>
# <tr><td>GES_DR5_1_V1</td><td>E_LI1</td><td>stat.error;phys.abund</td><td>REAL</td><td>Error on LI1</td><td>dex</td></tr>
# <tr><td>GES_DR5_1_V1</td><td>VEIL</td><td>spect</td><td>REAL</td><td>Veiling derived from spectral lines</td><td></td></tr>
# <tr><td>GES_DR5_1_V1</td><td>E_VEIL</td><td>stat.error;spect</td><td>REAL</td><td>Error on on VEIL</td><td></td></tr>
# <tr><td>GES_DR5_1_V1</td><td>EW_LI</td><td>spect.line.eqWidth</td><td>REAL</td><td>Li(6708A) equivalent width</td><td>Angstrom</td></tr>
# <tr><td>GES_DR5_1_V1</td><td>LIM_EW_LI</td><td>meta.code;spect.line.eqWidth</td><td>SMALLINT</td><td>Flag on EW_LI (0=detection, 1=upper limit)</td><td></td></tr>
# <tr><td>GES_DR5_1_V1</td><td>E_EW_LI</td><td>stat.error;spect.line.eqWidth</td><td>REAL</td><td>Error on EW_LI</td><td>Angstrom</td></tr>
# <tr><td>GES_DR5_1_V1</td><td>EWC_LI</td><td>spect.line.eqWidth</td><td>REAL</td><td>Blends-corrected Li(6708A) equivalent width</td><td>Angstrom</td></tr>
# <tr><td>GES_DR5_1_V1</td><td>LIM_EWC_LI</td><td>meta.code;spect.line.eqWidth</td><td>SMALLINT</td><td>Flag on EWC_LI (0=detection, 1=upper limit)</td><td></td></tr>
# <tr><td>GES_DR5_1_V1</td><td>E_EWC_LI</td><td>stat.error;spect.line.eqWidth</td><td>REAL</td><td>Error on EWC_LI</td><td>Angstrom</td></tr>
# <tr><td>GES_DR5_1_V1</td><td>HA10</td><td>spect.line.broad;em.line.Halpha</td><td>REAL</td><td>Halpha width at 10% of peak - accretion</td><td>km/s</td></tr>
# <tr><td>GES_DR5_1_V1</td><td>E_HA10</td><td>stat.error;spect.line.broad;em.line.Halpha</td><td>REAL</td><td>Error on HA10</td><td>km/s</td></tr>
# <tr><td>GES_DR5_1_V1</td><td>EW_HA_CHR</td><td>spect.line.eqWidth;em.line.Halpha</td><td>REAL</td><td>Halpha EW:

# %%
columns = archive_catalogues.columns_info(collections=['GAIAESO', 'AMBRE'])
columns.show_in_notebook(display_length=5, show_row_index=False)
# Out:
# <i>Table length=907</i>
# <table id="table140551082113584-799420" class="table-striped table-bordered table-condensed">
# <thead><tr><th>table_name</th><th>column_name</th><th>ucd</th><th>datatype</th><th>description</th><th>unit</th></tr></thead>
# <tr><td>AMBRE_V1</td><td>DP_ID</td><td>meta.id;meta.main</td><td>CHAR</td><td>ESO Data set identifier</td><td></td></tr>
# <tr><td>AMBRE_V1</td><td>OBJECT</td><td>meta.id</td><td>CHAR</td><td>Object designation</td><td></td></tr>
# <tr><td>AMBRE_V1</td><td>TARGNAME</td><td>meta.id</td><td>CHAR</td><td>Target designation</td><td></td></tr>
# <tr><td>AMBRE_V1</td><td>RAJ2000</td><td>pos.eq.ra;meta.main</td><td>REAL</td><td>Telescope pointing (right ascension, J2000)</td><td>deg</td></tr>
# <tr><td>AMBRE_V1</td><td>DEJ2000</td><td>pos.eq.dec;meta.main</td><td>REAL</td><td>Telescope pointing (declination, J2000)</td><td>deg</td></tr>
# <tr><td>AMBRE_V1</td><td>MJD_OBS</td><td>obs;time.epoch</td><td>DOUBLE</td><td>Start of observation date</td><td>MJD</td></tr>
# <tr><td>AMBRE_V1</td><td>EXPTIME</td><td>obs.exposure</td><td>REAL</td><td>Total integration time</td><td>s</td></tr>
# <tr><td>AMBRE_V1</td><td>SNR</td><td>stat.snr</td><td>REAL</td><td>Signal-to-noise ratio</td><td></td></tr>
# <tr><td>AMBRE_V1</td><td>SNR_FLAG</td><td>meta.code</td><td>CHAR</td><td>Quality of SNR estimate. (C)rude or (R)efined</td><td></td></tr>
# <tr><td>AMBRE_V1</td><td>EXTREME_EMISSION_LINE_FLAG</td><td>meta.code</td><td>CHAR</td><td>T if Extreme Emission Lines detected -&gt; No analysis</td><td></td></tr>
# <tr><td>AMBRE_V1</td><td>EMISSION_LINE_FLAG</td><td>meta.code</td><td>CHAR</td><td>T if some Emission Lines detected -&gt; Results Uncertain</td><td></td></tr>
# <tr><td>AMBRE_V1</td><td>MEANFWHM_LINES</td><td></td><td>REAL</td><td>Mean FWHM of absorption lines around 4500 Angstroem</td><td>Angstrom</td></tr>
# <tr><td>AMBRE_V1</td><td>MEANFWHM_LINES_FLAG</td><td>meta.code</td><td>CHAR</td><td>T if MEANFWHM_LINES outside the accepted range -&gt; Results Uncertain</td><td></td></tr>
# <tr><td>AMBRE_V1</td><td>VRAD</td><td>spect.dopplerVeloc</td><td>REAL</td><td>Radial Velocity</td><td>km/s</td></tr>
# <tr><td>AMBRE_V1</td><td>ERR_VRAD</td><td>stat.error;spect.dopplerVeloc</td><td>REAL</td><td>Error on the Radial Velocity</td><td>km/s</td></tr>
# <tr><td>AMBRE_V1</td><td>VRAD_CCF_FWHM</td><td>stat.correlation</td><td>REAL</td><td>FWHM of the CCF between the spectrum and the binary mask</td><td>Angstrom</td></tr>
# <tr><td>AMBRE_V1</td><td>VRAD_FLAG</td><td>meta.code.class</td><td>SMALLINT</td><td>Quality of the Vrad: 0=very good -&gt; 5=very bad</td><td></td></tr>
# <tr><td>AMBRE_V1</td><td>TEFF</td><td>phys.temperature.effective</td><td>REAL</td><td>Effective Temperature</td><td>K</td></tr>
# <tr><td>AMBRE_V1</td><td>ERR_INT_TEFF</td><td>stat.error;phys.temperature.effective</td><td>REAL</td><td>Effective Temperature Internal Error</td><td>K</td></tr>
# <tr><td>AMBRE_V1</td><td>ERR_EXT_TEFF</td><td>stat.error;phys.temperature.effective</td><td>REAL</td><td>Effective Temperature External Error</td><td>K</td></tr>
# <tr><td>AMBRE_V1</td><td>LOG_G</td><td>phys.gravity</td><td>REAL</td><td>Surface Gravity (log g)</td><td>cm/s^2</td></tr>
# <tr><td>AMBRE_V1</td><td>ERR_INT_LOG_G</td><td>stat.error;phys.gravity</td><td>REAL</td><td>Surface Gravity Internal Error</td><td>cm/s^2</td></tr>
# <tr><td>AMBRE_V1</td><td>ERR_EXT_LOG_G</td><td>stat.error;phys.gravity</td><td>REAL</td><td>Surface Gravity External Error</td><td>cm/s^2</td></tr>
# <tr><td>AMBRE_V1</td><td>M_H</td><td>phys.abund.Fe;stat.mean</td><td>REAL</td><td>Mean Metallicity [M/H]</td><td>dex</td></tr>
# <tr><td>AMBRE_V1</td><td>ERR_INT_M_H</td><td>stat.error;phys.abund.Fe</td><td>REAL</td><td>Mean Metallicity Internal Error</td><td>dex</td></tr>
# <tr><td>AMBRE_V1</td><td>ERR_EXT_M_H</td><td>stat.error;phys.abund.Fe</td><td>REAL</td><td>Mean Metallicity External Error</td><td>dex</td></tr>
# <tr><td>AMBRE_V1</td><td>ALPHA</td><td>phys.abund</td><td>REAL</td><td>Alpha elements over Iron abundances [Alpha/Fe]</td><td>dex</td></tr>
# <tr><td>AMBRE_V1</td><td>ERR_INT_ALPHA</td><td>stat.error;phys.abund</td><td>REAL</td><td>Alpha elements over Iron Enrichment Internal Error</td><td>dex</td></tr>
# <tr><td>AMBRE_V1</td><td>ERR_EXT_ALPHA</td><td>stat.error;phys.abund</td><td>REAL</td><td>Alpha elements over Iron Enrichment External Error</td><td>dex</td></tr>
# <tr><td>AMBRE_V1</td><td>CHI2</td><td>stat.fit.chi2</td><td>REAL</td><td>log(Chi^2) between the observed and reconstructed spectra</td><td></td></tr>
# <tr><td>AMBRE_V1</td><td>CHI2_FLAG</td><td>meta.code.class</td><td>SMALLINT</td><td>Quality Flag on this fit: 0=very good -&gt; 2=very bad</td><td></td></tr>
# <tr><td>AMBRE_V1</td><td>ORIGFILE</td><td>meta.id</td><td>CHAR</td><td>Filename of original spectrum being analysed</td><td></td></tr>
# <tr><td>AMBRE_V1</td><td>PROG_ID</td><td>meta.id</td><td>CHAR</td><td>ESO programme identifier</td><td></td></tr>
# <tr><td>GES_iDR4_PIII2016_Catalogue_v3_fits_V2</td><td>CNAME</td><td>meta.id;meta.main</td><td>CHAR</td><td>GES object name from coordinates</td><td></td></tr>
# <tr><td>GES_iDR4_PIII2016_Catalogue_v3_fits_V2</td><td>GES_FLD</td><td>meta.id</td><td>CHAR</td><td>GES field name from CASU</td><td></td></tr>
# <tr><td>GES_iDR4_PIII2016_Catalogue_v3_fits_V2</td><td>OBJECT</td><td>meta.id</td><td>CHAR</td><td>GES object name from OB</td><td></td></tr>
# <tr><td>GES_iDR4_PIII2016_Catalogue_v3_fits_V2</td><td>GES_TYPE</td><td>meta.code.member</td><td>CHAR</td><td>GES Classification System of Target Programmes</td><td></td></tr>
# <tr><td>GES_iDR4_PIII2016_Catalogue_v3_fits_V2</td><td>SETUP</td><td>instr.setup</td><td>CHAR</td><td>Grating setups used for analysis</td><td></td></tr>
# <tr><td>GES_iDR4_PIII2016_Catalogue_v3_fits_V2</td><td>RA</td><td>pos.eq.ra;meta.main</td><td>DOUBLE</td><td>Object Right Ascension</td><td>Degrees</td></tr>
# <tr><td>GES_iDR4_PIII2016_Catalogue_v3_fits_V2</td><td>DECLINATION</td><td>pos.eq.dec;meta.main</td><td>DOUBLE</td><td>Object Declination</td><td>Degrees</td></tr>
# <tr><td>GES_iDR4_PIII2016_Catalogue_v3_fits_V2</td><td>VRAD</td><td>spect.dopplerVeloc.opt</td><td>REAL</td><td>Radial Velocity</td><td>km/s</td></tr>
# <tr><td>GES_iDR4_PIII2016_Catalogue_v3_fits_V2</td><td>E_VRAD</td><td>stat.error;spect.dopplerVeloc.opt</td><td>REAL</td><td>Error on VRAD</td><td>km/s</td></tr>
# <tr><td>GES_iDR4_PIII2016_Catalogue_v3_fits_V2</td><td>TEFF</td><td>phys.temperature.effective</td><td>REAL</td><td>Effective Temperature</td><td>K</td></tr>
# <tr><td>GES_iDR4_PIII2016_Catalogue_v3_fits_V2</td><td>E_TEFF</td><td>stat.error;phys.temperature.effective</td><td>REAL</td><td>Error on TEFF</td><td>K</td></tr>
# <tr><td>GES_iDR4_PIII2016_Catalogue_v3_fits_V2</td><td>LOGG</td><td>phys.gravity</td><td>REAL</td><td>Log Surface Gravity (gravity in cms$^{-2}$)</td><td>dex</td></tr>
# <tr><td>GES_iDR4_PIII2016_Catalogue_v3_fits_V2</td><td>E_LOGG</td><td>stat.error;phys.gravity</td><td>REAL</td><td>Error on LOGG</td><td>dex</td></tr>
# <tr><td>GES_iDR4_PIII2016_Catalogue_v3_fits_V2</td><td>FEH</td><td>phys.abund.Fe</td><td>REAL</td><td>Metallicity</td><td>dex</td></tr>
# <tr><td>GES_iDR4_PIII2016_Catalogue_v3_fits_V2</td><td>E_FEH</td><td>stat.error;phys.abund.Fe</td><td>REAL</td><td>Error on FEH</td><td>dex</td></tr>
# <tr><td>GES_iDR4_PIII2016_Catalogue_v3_fits_V2</td><td>XI</td><td>phys.veloc.microTurb</td><td>REAL</td><td>Microturbulent velocity</td><td>km/s</td></tr>
# <tr><td>GES_iDR4_PIII2016_Catalogue_v3_fits_V2</td><td>E_XI</td><td>stat.error;phys.veloc.microTurb</td><td>REAL</td><td>Error on XI</td><td>km/s</td></tr>
# <tr><td>GES_iDR4_PIII2016_Catalogue_v3_fits_V2</td><td>EW_LI</td><td>spect.line.eqWidth</td><td>REAL</td><td>Li(6708A) equivalent width</td><td>mA</td></tr>
# <tr><td>GES_iDR4_PIII2016_Catalogue_v3_fits_V2</td><td>LIM_EW_LI</td><td>meta.code</td><td>SMALLINT</td><td>Flag on EW_LI (0=detection, 1=upper limit)</td><td></td></tr>
# <tr><td>GES_iDR4_PIII2016_Catalogue_v3_fits_V2</td><td>E_EW_LI</td><td>stat.error;spect.line.eqWidth</td><td>REAL</td>

# %% [markdown]
# Let assume we are interested in comparing the effective temperature and the gravity of the stars present in the queried catalogues. While these could have different names in different catalogues, it is possible to recover them using the `ucd` tokens. Specifically we select:
# * for the effective temperature:
# ```python
# columns['ucd']=='phys.temperature.effective'
# ```
# * for the gravity:
# ```python
# columns['ucd']=='phys.gravity'
# ```

# %%
columns[(columns['ucd']=='phys.temperature.effective') | (columns['ucd']=='phys.gravity')].show_in_notebook(display_length=5, show_row_index=False)
# Out:
# <i>Table length=12</i>
# <table id="table140550931101872-522330" class="table-striped table-bordered table-condensed">
# <thead><tr><th>table_name</th><th>column_name</th><th>ucd</th><th>datatype</th><th>description</th><th>unit</th></tr></thead>
# <tr><td>AMBRE_V1</td><td>TEFF</td><td>phys.temperature.effective</td><td>REAL</td><td>Effective Temperature</td><td>K</td></tr>
# <tr><td>AMBRE_V1</td><td>LOG_G</td><td>phys.gravity</td><td>REAL</td><td>Surface Gravity (log g)</td><td>cm/s^2</td></tr>
# <tr><td>GES_iDR4_PIII2016_Catalogue_v3_fits_V2</td><td>TEFF</td><td>phys.temperature.effective</td><td>REAL</td><td>Effective Temperature</td><td>K</td></tr>
# <tr><td>GES_iDR4_PIII2016_Catalogue_v3_fits_V2</td><td>LOGG</td><td>phys.gravity</td><td>REAL</td><td>Log Surface Gravity (gravity in cms$^{-2}$)</td><td>dex</td></tr>
# <tr><td>AMBRE_UVES_V1</td><td>TEFF</td><td>phys.temperature.effective</td><td>REAL</td><td>Effective Temperature</td><td>K</td></tr>
# <tr><td>AMBRE_UVES_V1</td><td>LOG_G</td><td>phys.gravity</td><td>REAL</td><td>Surface Gravity (log g)</td><td>cm.s**(-2)</td></tr>
# <tr><td>AMBRE_HARPS_V1</td><td>TEFF</td><td>phys.temperature.effective</td><td>REAL</td><td>Effective Temperature</td><td>K</td></tr>
# <tr><td>AMBRE_HARPS_V1</td><td>LOG_G</td><td>phys.gravity</td><td>REAL</td><td>Surface Gravity (log g)</td><td>cm.s**(-2)</td></tr>
# <tr><td>GES_DR5</td><td>TEFF</td><td>phys.temperature.effective</td><td>REAL</td><td>Effective Temperature</td><td>K</td></tr>
# <tr><td>GES_DR5</td><td>LOGG</td><td>phys.gravity</td><td>REAL</td><td>Log Surface Gravity (gravity in cm/s**2)</td><td>log(cm/s**2)</td></tr>
# <tr><td>GES_DR5_1_V1</td><td>TEFF</td><td>phys.temperature.effective</td><td>REAL</td><td>Effective Temperature</td><td>K</td></tr>
# <tr><td>GES_DR5_1_V1</td><td>LOGG</td><td>phys.gravity</td><td>REAL</td><td>Log Surface Gravity (gravity in cm/s**2)</td><td>log(cm/s**2)</td></tr>
# </table><style>table.dataTable {clear: both; width: auto !important; margin: 0 !important;}
# .dataTables_info, .dataTables_length, .dataTables_filter, .dataTables_paginate{
# display: inline-block; margin-right: 1em; }
# .paginate_button { margin-right: 5px; }
# </style>
# <script>
#
# var astropy_sort_num = function(a, b) {
#     var a_num = parseFloat(a);
#     var b_num = parseFloat(b);
#
#     if (isNaN(a_num) && isNaN(b_num))
#         return ((a < b) ? -1 : ((a > b) ? 1 : 0));
#     else if (!isNaN(a_num) && !isNaN(b_num))
#         return ((a_num < b_num) ? -1 : ((a_num > b_num) ? 1 : 0));
#     else
#         return isNaN(a_num) ? -1 : 1;
# }
#
# require.config({paths: {
#     datatables: 'https://cdn.datatables.net/1.10.12/js/jquery.dataTables.min'
# }});
# require(["datatables"], function(){
#     console.log("$('#table140550931101872-522330').dataTable()");
#
# jQuery.extend( jQuery.fn.dataTableExt.oSort, {
#     "optionalnum-asc": astropy_sort_num,
#     "optionalnum-desc": function (a,b) { return -astropy_sort_num(a, b); }
# });
#
#     $('#table140550931101872-522330').dataTable({
#         order: [],
#         pageLength: 5,
#         lengthMenu: [[5, 10, 25, 50, 100, 500, 1000, -1], [5, 10, 25, 50, 100, 500, 1000, 'All']],
#         pagingType: "full_numbers",
#         columnDefs: [{targets: [], type: "optionalnum"}]
#     });
# });
# </script>

# %% [markdown]
# The result is thus stored in an `astropy.table`:

# %% [markdown]
# ## Explore the data
#
# Now you have all the information to obtain data from the `AMBRE` and `GAIAESO` catalogues.
#
# Note that, to speed up the process, we queried the table for only the columns we are interested in, i.e. 'TEFF', 'LOG_G' for `AMBRE` and 'TEFF', 'LOGG' for `GAIAESO`.
#
# Note that the collection `AMBRE` contains to tables (`AMBRE_V1` and `AMBRE_UVES_V1`), thus data will be stored in a list of astropy tables (one per table).

# %%
selected_columns_ambre = ['TEFF', 'LOG_G']
selected_columns_gaiaeso = ['TEFF', 'LOGG']

ambre = archive_catalogues.get_catalogues(tables=['AMBRE_UVES_V1', 'AMBRE_V1'], columns=selected_columns_ambre)
gaiaeso = archive_catalogues.get_catalogues(tables='GES_DR5_1_V1', columns=selected_columns_gaiaeso)
# Out:
# [INFO]    :: The query to AMBRE_UVES_V1 returned 51897 entries (with a limit set to maxrec=51897)
# [INFO]    :: The query to AMBRE_V1 returned 18618 entries (with a limit set to maxrec=18618)
# [INFO]    :: The query to GES_DR5_1_V1 returned 114916 entries (with a limit set to maxrec=114916)

# %% [markdown]
# Now the coverage of the different surveys on the effective temperature vs. gravity plot can be plotted.

# %%
tables = ['AMBRE_UVES_V1', 'AMBRE_V1', 'GES_DR5_1_V1']
catalogues = ambre + [gaiaeso]
cmaps = ['gist_earth_r', 'gist_earth_r', 'gnuplot2_r']

fig, axes = plt.subplots(ncols=3, nrows=1, 
                         sharex=True, sharey=True,
                        figsize=(10,2.5))

for table, catalogue, ax, cmap in zip(tables, catalogues, axes, cmaps):

    if table.startswith('AMBRE'):
        teff = catalogue[selected_columns_ambre[0]]
        logg = catalogue[selected_columns_ambre[1]]
    else:
        teff = catalogue[selected_columns_gaiaeso[0]]
        logg = catalogue[selected_columns_gaiaeso[1]]

    ax.set_title(r'{}'.format(table))
    ax.set_xlim(3000, 9000)
    ax.set_ylim(5.49, 0.01)
    ax_plot = ax.hexbin(teff, logg, cmap=cmap, gridsize=30, extent=(2500, 1e4, 6, 0), linewidths=0.1)
    plt.colorbar(ax_plot, ax=ax)
    
fig.text(0.5, -0.02, r'$T_{eff}$ (K)', ha='center', size='large')
fig.text(0.08, 0.5, r'$\log\,g$ (dex)', va='center', rotation='vertical', size='large')
fig.text(0.92, 0.5, r'# of stars', va='center', rotation=-90., size='large')

fig.savefig('figures/ambre_vs_gaiaeso.png', bbox_inches='tight')

# %% [markdown]
# Or, to show the distribution of the data in `AMBRE_UVES_V1` in bin normalized in $\log_{10}$

# %%
teff = catalogue[selected_columns_gaiaeso[0]]
logg = catalogue[selected_columns_gaiaeso[1]]

fig, ax = plt.subplots(ncols=1, nrows=1, 
                         sharex=True, sharey=True,
                        figsize=(3,2.5))

ax.set_title('GES_DR5_1_V1')
ax.set_xlim(3000, 9000)
ax.set_ylim(5.49, 0.01)
ax_plot = ax.hexbin(teff, logg, cmap='afmhot_r', gridsize=40, extent=(2500, 1e4, 6, 0), linewidths=0.1, bins='log')
cbar = plt.colorbar(ax_plot, ax=ax)
    
ax.set_xlabel(r'$T_{eff}$ (K)')
ax.set_ylabel(r'$\log\,g$ (dex)')
cbar.set_label(r'# of stars')

fig.savefig('figures/gaiaeso.png', bbox_inches='tight')
